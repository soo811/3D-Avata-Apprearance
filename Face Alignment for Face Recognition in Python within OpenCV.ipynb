# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from PIL import Image

# %% [markdown]
# ## 환경설정

# %%
face_detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
eye_detector = cv2.CascadeClassifier("haarcascade_eye.xml")

# %% [markdown]
# ## 이미지 로드

# %%
img = cv2.imread("./testimg/cha.jpg")
img_raw = img.copy()
plt.imshow(img[:, :, ::-1])

# %% [markdown]
# ## 얼굴 탐지

# %%
faces = face_detector.detectMultiScale(img, 1.3, 5)
face_x, face_y, face_w, face_h = faces[0]

img = img[int(face_y):int(face_y + face_h), int(face_x):int(face_x + face_w)]
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# ## 눈 탐지

# %%
eyes = eye_detector.detectMultiScale(img_gray)

index = 0

for (eye_x, eye_y, eye_w, eye_h) in eyes:
    if index == 0:
        eye_1 = (eye_x, eye_y, eye_w, eye_h)
    elif index == 1:
        eye_2 = (eye_x, eye_y, eye_w ,eye_h)
        
    cv2.rectangle(img, (eye_x, eye_y), (eye_x + eye_w, eye_y + eye_h), (0, 0, 255), 2)
    index = index + 1
    
plt.imshow(img[:, :, ::-1])

# %%
if eye_1[0] < eye_2[0]:
    left_eye = eye_1
    right_eye = eye_2
else:
    left_eye = eye_2
    right_eye = eye_1

# %% [markdown]
# ## 좌표
#
# * 인덱스
#     * 0 : x
#     * 1 : y
#     * 2 : w
#     * 3 : h

# %%
left_eye_center = (int(left_eye[0] + (left_eye[2] / 2)), int(left_eye[1] + (left_eye[3] / 2)))
left_eye_x = left_eye_center[0]
left_eye_y = left_eye_center[1]

right_eye_center = (int(right_eye[0] + (right_eye[2] / 2)), int(right_eye[1] + (right_eye[3] / 2)))
right_eye_x = right_eye_center[0]
right_eye_y = right_eye_center[1]

cv2.circle(img, left_eye_center, 2, (255, 0, 0), 2)
cv2.circle(img, right_eye_center, 2, (255, 0, 0), 2)
cv2.line(img, right_eye_center, left_eye_center, (67, 67,67), 2)

plt.imshow(img[:, :, ::-1])

# %% [markdown]
# ## 눈 회전방향 결정
# * 왼쪽 눈이 오른쪽 눈보다 위 : 반시계 방향
# * 왼쪽 눈이 오른쪽 눈보다 아래 : 시계 방향
#
# <b>OpenCV의 원점이 좌측상단이라는 것에 주의하자!</b><br>
# <b>각도의 증가 또한 반시계 방향으로 증가한다는 것에 주의하자.</b><br>

# %%
if left_eye_y < right_eye_y :
    point_3rd = (right_eye_x, left_eye_y)
    direction = 1 # 반시계방향
    print("반시계방향 회전")
else:
    point_3rd = (left_eye_x, right_eye_y)
    direction = -1 # 시계방향
    print("시계방향 회전")
    
cv2.circle(img, point_3rd, 2, (255, 0, 0), 2)

cv2.line(img, right_eye_center, left_eye_center, (67, 67, 67), 2)
cv2.line(img, left_eye_center, point_3rd, (67, 67, 67), 2)
cv2.line(img, right_eye_center, point_3rd, (67, 67, 67), 2)

plt.imshow(img[:, :, ::-1])
# Out:
# 시계방향 회전

# %% [markdown]
# ## 유클리드 거리

# %%
import math

def euclidean_distance(a, b):
    x1 = a[0]
    y1 = a[1]
    x2 = b[0]
    y2 = b[1]
    
    return math.sqrt((x2 - x1) * (x2 - x1) + (y2 - y1)* (y2 - y1))

# %%
a = euclidean_distance(left_eye_center, point_3rd)
b = euclidean_distance(right_eye_center, left_eye_center)
c = euclidean_distance(right_eye_center, point_3rd)

print("a : ", a, ", b : ", b, ", c : ", c)
# Out:
# a :  16.0 , b :  78.64477096412705 , c :  77.0

# %% [markdown]
# ## 회전 각도 계산
# * 코사인 법칙 :
# $cos(A) = (b^2 + c^2 - a^2) \div (2bc)$

# %%
cos_a = (b * b + c * c - a * a) / (2 * b * c)
print("cos(a) = ", cos_a)

angle = np.arccos(cos_a)
print("angle : " , angle, " in radian")

angle = (angle * 180) / math.pi
print("angle : ", angle, " in degree")

if direction == 1:
    angle = 90 - angle
# Out:
# cos(a) =  0.9790860734418403
# angle :  0.20487671703710858  in radian
# angle :  11.73857120672233  in degree

# %% [markdown]
# ## 이미지 회전

# %%
new_img = Image.fromarray(img_raw)
new_img = np.array(new_img.rotate(direction * angle))

print("direction : ", direction)
print("angle : ", angle)

plt.imshow(new_img[:,:,::-1])
# Out:
# direction :  -1
# angle :  11.73857120672233

# %% [markdown]
# ## 확인

# %%
raw_new_img = new_img.copy()

faces = face_detector.detectMultiScale(new_img, 1.3, 5)
face_x, face_y, face_w, face_h = faces[0]

new_img = new_img[int(face_y):int(face_y + face_h), int(face_x):int(face_x + face_w)]

plt.imshow(new_img)

# %% [markdown]
# ## DeepFace 사용

# %%
pip install DeepFace
# Out:
# Collecting DeepFace
#   Downloading deepface-0.0.79-py3-none-any.whl (49 kB)
#      ---------------------------------------- 49.6/49.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in c:\users\jisoo\anaconda3\lib\site-packages (from DeepFace) (1.23.5)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\jisoo\anaconda3\lib\site-packages (from DeepFace) (1.5.3)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\jisoo\anaconda3\lib\site-packages (from DeepFace) (4.64.1)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\jisoo\anaconda3\lib\site-packages (from DeepFace) (9.4.0)
# Collecting retina-face>=0.0.1
#   Downloading retina_face-0.0.13-py3-none-any.whl (16 kB)
# Collecting gdown>=3.10.1
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ---------------------------------------- 80.2/80.2 kB 4.7 MB/s eta 0:00:00
# Collecting mtcnn>=0.1.0
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ---------------------------------------- 2.3/2.3 MB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\jisoo\anaconda3\lib\site-packages (from DeepFace) (2.12.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\jisoo\anaconda3\lib\site-packages (from DeepFace) (2.12.0)
# Collecting fire>=0.4.0
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ---------------------------------------- 88.3/88.3 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Flask>=1.1.2 in c:\users\jisoo\anaconda3\lib\site-packages (from DeepFace) (2.2.2)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\jisoo\anaconda3\lib\site-packages (from DeepFace) (4.8.0.74)
# Requirement already satisfied: six in c:\users\jisoo\anaconda3\lib\site-packages (from fire>=0.4.0->DeepFace) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\jisoo\anaconda3\lib\site-packages (from fire>=0.4.0->DeepFace) (2.3.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\jisoo\anaconda3\lib\site-packages (from Flask>=1.1.2->DeepFace) (2.2.2)
# Requirement already satisfied: click>=8.0 in c:\users\jisoo\anaconda3\lib\site-packages (from Flask>=1.1.2->DeepFace) (8.0.4)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jisoo\anaconda3\lib\site-packages (from Flask>=1.1.2->DeepFace) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jisoo\anaconda3\lib\site-packages (from Flask>=1.1.2->DeepFace) (2.0.1)
# Requirement already satisfied: filelock in c:\users\jisoo\anaconda3\lib\site-packages (from gdown>=3.10.1->DeepFace) (3.9.0)
# Requirement already satisfied: requests[socks] in c:\users\jisoo\anaconda3\lib\site-packages (from gdown>=3.10.1->DeepFace) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\jisoo\anaconda3\lib\site-packages (from gdown>=3.10.1->DeepFace) (4.11.1)
# Requirement already satisfied: packaging in c:\users\jisoo\anaconda3\lib\site-packages (from gunicorn>=20.1.0->DeepFace) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jisoo\anaconda3\lib\site-packages (from pandas>=0.23.4->DeepFace) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jisoo\anaconda3\lib\site-packages (from pandas>=0.23.4->DeepFace) (2.8.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow>=1.9.0->DeepFace) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (1.4.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (2.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (3.3.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (2.12.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (4.4.0)
# Requirement already satisfied: setuptools in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (65.6.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (3.20.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (23.5.26)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.2.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.4.13)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (1.56.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (16.0.0)
# Requirement already satisfied: colorama in c:\users\jisoo\anaconda3\lib\site-packages (from tqdm>=4.30.0->DeepFace) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jisoo\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->DeepFace) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jisoo\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->DeepFace) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jisoo\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->DeepFace) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jisoo\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->DeepFace) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jisoo\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->DeepFace) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jisoo\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->DeepFace) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\jisoo\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->DeepFace) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jisoo\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\jisoo\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (1.10.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\jisoo\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (2.21.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jisoo\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.7.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jisoo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jisoo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jisoo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jisoo\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jisoo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jisoo\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow>=1.9.0->DeepFace) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116947 sha256=c973d8d44fcf390556b0b279d766c6dde4c26819990b77e776c4beae2b4e1d41
#   Stored in directory: c:\users\jisoo\appdata\local\pip\cache\wheels\c4\eb\6a\1c6d2ad660043768e998bdf9c6a28db2f1b7db3a5825d51e87
# Successfully built fire
# Installing collected packages: gunicorn, fire, mtcnn, gdown, retina-face, DeepFace
# Successfully installed DeepFace-0.0.79 fire-0.5.0 gdown-4.7.1 gunicorn-21.2.0 mtcnn-0.1.1 retina-face-0.0.13
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepface import DeepFace
# Out:
# Directory  C:\Users\jisoo /.deepface created
# Directory  C:\Users\jisoo /.deepface/weights created

# %%
aligned_face = DeepFace.detectFace("testimg/cha.jpg")
plt.imshow(aligned_face)
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
