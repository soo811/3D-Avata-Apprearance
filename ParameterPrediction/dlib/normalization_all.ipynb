# %%
import cv2
import numpy as np
import dlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
for i in range(100):
    face_path = './dataset/train/img/%s.png'%i
    face_origin = cv2.imread(face_path)
    face_copy = face_origin.copy()
    face_rgb = cv2.cvtColor(face_copy, cv2.COLOR_BGR2RGB)
    
    detector = dlib.get_frontal_face_detector()
    dlib_rects = detector(face_rgb, 1)
    
    img_how_rgb = cv2.cvtColor(face_copy, cv2.COLOR_BGR2RGB)
    
    predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
    
    globals()['height'+str(i)] = face_origin.shape[0]
    
    globals()['img'+str(i)] = []
    
    for dlib_rect in dlib_rects:
        points = predictor(face_rgb, dlib_rect)
        list_points = list(map(lambda p: [p.x, p.y], points.parts()))
        globals()['img'+str(i)].append(list_points)
        globals()['img'+str(i)] = np.array(globals()['img'+str(i)])

# %%
face_origin.shape
# Out:
# (1080, 800, 3)

# %%
for i in range(100):
    land = np.zeros((68,2))
    
    for j in range(68):
        land[j][0] = globals()['img'+str(i)][0][j][0]
        land[j][1] = globals()['img'+str(i)][0][j][1]
        
    x = land[:,0]
    y = land[:,1] * (-1) + globals()['height'+str(i)]
    
    x -= ((min(x) + max(x)) / 2)
    y -= ((min(y) + min(y)) / 2)
    
    norm_x = (x - min(x)) / (max(y)-min(y))
    norm_y = (y - min(y)) / (max(y)-min(y))
    
    globals()['norm'+str(i)] = np.column_stack((norm_x, norm_y))

# %%
for i in range(100):
    globals()['norm'+str(i)] = globals()['norm'+str(i)].flatten()

# %%
train_x = np.zeros((100, len(norm0)))
for i in range(100):
    for j in range(len(norm0)):
        train_x[i][j] = globals()['norm'+str(i)][j]

# %%
for i in range(100):
    face_path = './dataset/test/img/%s.png'%i
    face_origin = cv2.imread(face_path)
    face_copy = face_origin.copy()
    face_rgb = cv2.cvtColor(face_copy, cv2.COLOR_BGR2RGB)
    
    detector = dlib.get_frontal_face_detector()
    dlib_rects = detector(face_rgb, 1)
    
    img_how_rgb = cv2.cvtColor(face_copy, cv2.COLOR_BGR2RGB)
    
    predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
    
    globals()['height'+str(i)] = face_origin.shape[0]
    
    globals()['img'+str(i)] = []
    
    for dlib_rect in dlib_rects:
        points = predictor(face_rgb, dlib_rect)
        list_points = list(map(lambda p: [p.x, p.y], points.parts()))
        globals()['img'+str(i)].append(list_points)
        globals()['img'+str(i)] = np.array(globals()['img'+str(i)])

# %%
for i in range(100):
    land = np.zeros((68,2))
    
    for j in range(68):
        land[j][0] = globals()['img'+str(i)][0][j][0]
        land[j][1] = globals()['img'+str(i)][0][j][1]
        
    x = land[:,0]
    y = land[:,1] * (-1) + globals()['height'+str(i)]
    
    x -= ((min(x) + max(x)) / 2)
    y -= ((min(y) + min(y)) / 2)
    
    norm_x = (x - min(x)) / (max(y)-min(y))
    norm_y = (y - min(y)) / (max(y)-min(y))
    
    globals()['norm'+str(i)] = np.column_stack((norm_x, norm_y))

# %%
# xyxyxyxyxyxyxy(0~16)
for i in range(100):
    globals()['norm'+str(i)] = globals()['norm'+str(i)].flatten()

# %%
test_x = np.zeros((100, len(norm0)))
for i in range(100):
    for j in range(len(norm0)):
        test_x[i][j] = globals()['norm'+str(i)][j]

# %%
train_y = pd.read_csv('./dataset/train/train.csv')
train_y = train_y.iloc[:, 1:]
test_y = pd.read_csv('./dataset/test/test.csv')
test_y = test_y.iloc[:, 1:]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

model = LinearRegression()
model.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(test_x)
mae = mean_absolute_error(test_y, y_pred)

mae
# Out:
# 0.18457921807762523

# %%
# model.intercept_, model.coef_

# %%
# pd.set_option('display.max_rows', None)

# %%
prediction = pd.DataFrame(y_pred)
prediction
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.771234  1.118781  0.531712  0.302476  0.394549  0.528928  0.449102
# 1   0.247510  0.291930  0.381500  0.532705  0.521296  1.226171  0.401919
# 2   0.697533  0.595013  0.260704  0.693290  0.641035  0.680069  0.861969
# 3   0.767827  0.590607  0.821778  0.518725  0.649510  0.854301  0.572729
# 4   0.729931  0.809909  0.432729  0.335792  0.130008  0.214551  0.698552
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.526149  0.837567  0.359294  0.904720  0.111204  0.312500  0.450635
# 96  0.182872  0.767193  0.512970  0.559017  0.513637  0.489154  0.415459
# 97  0.328398  0.679752  0.327952  0.582920  0.638698  0.581815  0.092681
# 98  0.327588  0.735953  0.502151  0.686129  0.440452  0.434073  0.425205
# 99  0.706238  1.066239  1.082771  0.762466  0.539780  1.100920 -0.083594
#
#           7         8         9   ...        23        24        25        26  \
# 0   0.340005  0.351375  0.291421  ...  0.659978  0.723826  0.511786  0.117757
# 1   0.492405 -0.053191  0.628748  ...  0.436595  0.710702  0.375467  0.349192
# 2   0.640651  0.728656  0.650495  ...  0.586084  1.020113  0.587903  0.408638
# 3   0.879431  0.934078  0.279022  ...  0.397163  0.029057  0.238033  0.356834
# 4   0.393421  0.356673  0.369151  ...  0.123734  0.741844  0.334278  0.586551
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  0.434492  0.420800  1.051561  ... -0.039867  0.713671  0.374849  0.460453
# 96  0.288237  0.591904  0.623296  ...  0.429573  0.458314  0.427663  0.507237
# 97  0.685464  0.724886  0.550882  ...  0.514194  0.565998  0.423103  0.218379
# 98  0.635186  0.826952  1.130827  ...  0.091880  0.692196  0.700776  0.392035
# 99  0.297957  0.524096  0.225120  ...  0.898650  0.507760  0.493041  0.311357
#
#           27        28        29        30        31        32
# 0   0.260611  0.534306  0.336152  0.678083  0.566384  0.578440
# 1   0.456623  0.499415  0.282767  0.622986  0.395680  0.690890
# 2   0.713942  0.182887  0.189153  0.760967  0.597048  0.491811
# 3  -0.072655  0.599266  0.510217  0.227250  0.424878  0.265183
# 4   0.967962  0.604939  0.633491  0.886773  0.751773  0.436064
# ..       ...       ...       ...       ...       ...       ...
# 95  0.663721  0.663691  0.555352  0.345520  0.730728  0.321768
# 96  1.088549  0.453823  0.638083  0.285770  0.241970  0.693065
# 97  0.698843  0.809152  0.444042  0.208077  0.543625  0.471361
# 98  0.362456  0.098681  0.617637  0.227959  0.178079  0.619264
# 99  0.239441  0.056109  0.331624  0.413231  0.125889  0.736822
#
# [100 rows x 33 columns]

# %%
test_y
# Out:
#     headSize  headWidth  foreheadPosition  foreheadSize  jawsPosition  \
# 0   0.791202   0.751415          0.607003      0.283281      0.323832
# 1   0.386834   0.339232          0.432180      0.483835      0.252126
# 2   0.574762   0.699237          0.411268      0.750323      0.466237
# 3   0.479228   0.394898          0.551559      0.581309      0.289253
# 4   0.354949   0.772665          0.370712      0.740097      0.225629
# ..       ...        ...               ...           ...           ...
# 95  0.733386   0.741005          0.744977      0.330086      0.320538
# 96  0.578829   0.502118          0.411282      0.518884      0.530781
# 97  0.484565   0.278518          0.452158      0.550655      0.565084
# 98  0.797103   0.286901          0.619084      0.437765      0.569411
# 99  0.538591   0.626917          0.457781      0.325516      0.622268
#
#     jawsSize  chinPosition  chinSize  chinPronounced  lowCheek  ...  \
# 0   0.595424      0.420894  0.251898        0.237049  0.307233  ...
# 1   0.766253      0.768240  0.637456        0.350807  0.576077  ...
# 2   0.531876      0.502866  0.621738        0.414447  0.512559  ...
# 3   0.519737      0.526797  0.793071        0.759815  0.435258  ...
# 4   0.502349      0.339251  0.652542        0.210893  0.585627  ...
# ..       ...           ...       ...             ...       ...  ...
# 95  0.766127      0.231935  0.399568        0.201140  0.226019  ...
# 96  0.438227      0.651389  0.252586        0.348231  0.723990  ...
# 97  0.416299      0.286769  0.596652        0.647926  0.719077  ...
# 98  0.301160      0.784193  0.403280        0.583085  0.798517  ...
# 99  0.681516      0.325438  0.217985        0.300964  0.524027  ...
#
#     noseFlatten  nosePronounced  noseWidth  noseBridge  noseCurve  \
# 0      0.204617        0.362828   0.274802    0.260083   0.561282
# 1      0.319688        0.499098   0.544562    0.494427   0.490545
# 2      0.752782        0.587933   0.600885    0.460328   0.622252
# 3      0.551737        0.515948   0.380126    0.557269   0.291789
# 4      0.604129        0.722225   0.600525    0.364166   0.531541
# ..          ...             ...        ...         ...        ...
# 95     0.242632        0.437827   0.438891    0.276147   0.233988
# 96     0.258576        0.706496   0.402938    0.243166   0.505273
# 97     0.213180        0.699112   0.250577    0.256895   0.588393
# 98     0.262559        0.505704   0.792901    0.338591   0.532779
# 99     0.698750        0.274729   0.654299    0.350763   0.493383
#
#     noseInclination  mouthSize  mouthPosition  mouthPronounced  lipsSize
# 0          0.678466   0.241427       0.614988         0.780424  0.520251
# 1          0.507280   0.298667       0.704906         0.733134  0.742770
# 2          0.239924   0.228592       0.651212         0.317283  0.440955
# 3          0.655423   0.481674       0.214611         0.633301  0.222423
# 4          0.696418   0.676315       0.793210         0.581524  0.521908
# ..              ...        ...            ...              ...       ...
# 95         0.738699   0.549648       0.204712         0.569278  0.322924
# 96         0.341421   0.617910       0.485857         0.463260  0.680530
# 97         0.682466   0.445559       0.314909         0.787422  0.434210
# 98         0.310331   0.660861       0.420872         0.230623  0.670635
# 99         0.377706   0.291226       0.799739         0.536911  0.646169
#
# [100 rows x 33 columns]

# %%
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(test_y, prediction)**0.5
print(rmse)
# Out:
# 0.12550871680663447
